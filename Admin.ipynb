# %%
from Manage_Forcastings import getSaveSimpleTimeSeriesPred_LSTM

# %%
tickers =["NVDA","TSLA","GOOG","IBM","LCID", "AMZN","META"]

# %%
for ticker in tickers:
    predictions, train_pred,test_pred, _ = getSaveSimpleTimeSeriesPred_LSTM(ticker,loop_back=10, number_of_dense_layers=2, timePeriod="full", save_results=True)
# Out:
# Fetching the stock Data from Alpha Vintage...
# Fetching Sucessfull!
# Getting predictions
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_4 (LSTM)               (None, 200)               168800
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_4 (Dense)             (None, 2)                 402
#
# ...
# Total params: 169,202
# Trainable params: 169,202
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...
# 12/12 [==============================] - 0s 5ms/step
# Train Mean Absolute Error: 334.92517
# Train Root Mean Squared Error: 370.72742
# Test Mean Absolute Error: 225.58345
# Test Root Mean Squared Error: 232.55891
# Got the Predictions Sucessfully!
# Results Saved Sucesfully!
# Fetching the stock Data from Alpha Vintage...
# Fetching Sucessfull!
# Getting predictions
# Model: "sequential_5"
# ...

# %%
predictions, train_pred,test_pred, _ = getSaveSimpleTimeSeriesPred_LSTM("GOOG",loop_back=15, number_of_dense_layers=3, timePeriod="full" , save_results=True)
# Out:
# Fetching the stock Data from Alpha Vintage...
# Fetching Sucessfull!
# Getting predictions
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 200)               172800
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 3)                 603
#
# ...
# Total params: 173,403
# Trainable params: 173,403
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...
# 5/5 [==============================] - 0s 5ms/step
# Train Mean Absolute Error: 0.03507275
# Train Root Mean Squared Error: 0.0707408
# Test Mean Absolute Error: 0.011941034
# Test Root Mean Squared Error: 0.012044277
# Got the Predictions Sucessfully!
# Results Saved Sucesfully!
